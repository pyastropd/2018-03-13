# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# /Users/eleonoraalei/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2862: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df=pd.read_csv('meteorite-landings.csv',encoding='latin1') #sep=',', index_col='id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
# name           45716 non-null object
# id             45716 non-null int64
# nametype       45716 non-null object
# recclass       45716 non-null object
# mass           45585 non-null float64
# fall           45716 non-null object
# year           45428 non-null float64
# reclat         38401 non-null float64
# reclong        38401 non-null float64
# GeoLocation    38401 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
df.sort_index(axis=0)
# Out:
#                       name     id nametype              recclass       mass  \
# 0                   Aachen      1    Valid                    L5       21.0
# 1                   Aarhus      2    Valid                    H6      720.0
# 2                     Abee      6    Valid                   EH4   107000.0
# 3                 Acapulco     10    Valid           Acapulcoite     1914.0
# 4                  Achiras    370    Valid                    L6      780.0
# 5                 Adhi Kot    379    Valid                   EH4     4239.0
# 6      Adzhi-Bogdo (stone)    390    Valid                 LL3-6      910.0
# 7                     Agen    392    Valid                    H5    30000.0
# 8                   Aguada    398    Valid                    L6     1620.0
# 9            Aguila Blanca    417    Valid                     L     1440.0
# 10        Aioun el Atrouss    423    Valid          Diogenite-pm     1000.0
# ...

# %%
df.sort_values(by=['id'],axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
# Out:
#                          name     id nametype     recclass       mass   fall  \
# 0                      Aachen      1    Valid           L5      21.00   Fell
# 1                      Aarhus      2    Valid           H6     720.00   Fell
# 1108                    Abajo      4    Valid           H5     331.00  Found
# 1110                   Abbott      5    Valid         H3-6   21100.00  Found
# 2                        Abee      6    Valid          EH4  107000.00   Fell
# 1111                Abernathy      7    Valid           L6    2914.00  Found
# 1112                      Abo      8    Valid            H       1.20  Found
# 1113              Abu Moharek      9    Valid           H4    4500.00  Found
# 3                    Acapulco     10    Valid  Acapulcoite    1914.00   Fell
# 1114                Acfer 001     11    Valid           L6    6700.00  Found
# 1115                Acfer 002     12    Valid           H5     228.00  Found
# ...

# %%
df2=df[(df.year>=1900.)&(df.year<=2016)]
#df2['year'].hist(bins=50)
#df2.year[df2.recclass=="L5"].hist(bins=50)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44696 entries, 1 to 45715
# Data columns (total 10 columns):
# name           44696 non-null object
# id             44696 non-null int64
# nametype       44696 non-null object
# recclass       44696 non-null object
# mass           44598 non-null float64
# fall           44696 non-null object
# year           44696 non-null float64
# reclat         37499 non-null float64
# reclong        37499 non-null float64
# GeoLocation    37499 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.8+ MB

# %%
df3=df.loc[lambda df: (df.year>=1900.)&(df.year<=2016), :]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44696 entries, 1 to 45715
# Data columns (total 10 columns):
# name           44696 non-null object
# id             44696 non-null int64
# nametype       44696 non-null object
# recclass       44696 non-null object
# mass           44598 non-null float64
# fall           44696 non-null object
# year           44696 non-null float64
# reclat         37499 non-null float64
# reclong        37499 non-null float64
# GeoLocation    37499 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.8+ MB

# %%
df['recclass'].value_counts()
# Out:
# L6                     8285
# H5                     7142
# L5                     4796
# H6                     4528
# H4                     4211
# LL5                    2766
# LL6                    2043
# L4                     1253
# H4/5                    428
# CM2                     416
# H3                      386
# L3                      365
# CO3                     335
# Ureilite                300
# Iron, IIIAB             285
# LL4                     268
# CV3                     256
# Diogenite               241
# Howardite               240
# LL                      225
# Eucrite                 221
# Eucrite-pmict           207
# E3                      206
# H5/6                    193
# Mesosiderite            137
# CR2                     135
# LL3                     128
# EH3                     120
# Iron, IIAB              118
# Iron, ungrouped         113
#                        ...
# LL3.8-4                   1
# CM2-an                    1
# ...

# %%
rccounts = df['recclass'].value_counts()
rccounts[:10]
# Out:
# L6      8285
# H5      7142
# L5      4796
# H6      4528
# H4      4211
# LL5     2766
# LL6     2043
# L4      1253
# H4/5     428
# CM2      416
# Name: recclass, dtype: int64

# %%
rccounts[:10].plot(kind='bar')

# %%
 df2.mass.value_counts()
# Out:
# 1.300        171
# 1.200        138
# 1.400        138
# 2.100        130
# 2.400        126
# 1.600        120
# 0.500        118
# 1.100        116
# 3.800        114
# 0.700        111
# 1.500        111
# 3.100        109
# 3.200        109
# 1.700        109
# 0.900        108
# 0.600        108
# 3.000        107
# 0.800        106
# 1.800        104
# 2.500        103
# 2.700        102
# 3.600         96
# 4.200         95
# 2.000         95
# 1.000         95
# 2.800         93
# 2.900         93
# 2.200         92
# 2.600         91
# 3.300         88
#             ...
# 21.942         1
# 61.130         1
# 220.900        1
# 183.300        1
# 19.880         1
# 3178.500       1
# 65.210         1
# 242.580        1
# 2538.000       1
# 69.630         1
# 1922.000       1
# 485.920        1
# 156.740        1
# 84.310         1
# 376.200        1
# 12050.000      1
# 14764.000      1
# 85.690         1
# 176.100        1
# 224.900        1
# 10667.000      1
# ...

# %%
 df.where(s > 0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44696 entries, 1 to 45715
# Data columns (total 10 columns):
# name           44696 non-null object
# id             44696 non-null int64
# nametype       44696 non-null object
# recclass       44696 non-null object
# mass           44598 non-null float64
# fall           44696 non-null object
# year           44696 non-null float64
# reclat         37499 non-null float64
# reclong        37499 non-null float64
# GeoLocation    37499 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 5.0+ MB
